# %% [markdown]
# # Explore LLNL ESGF holdings
#
# Use this notebook to explore the LLNL ESGF holdings and determine which grid we should use for each of the models. Most models only have one grid, but some have more and we need to explicitly define the best choice. The bottom of the notebook includes the justification for each model.

# %%
import numpy as np
import pandas as pd
from itertools import chain

# %% [markdown]
# Read a CSV containing info on holdings. Since empty directories are listed here, remove any rows where number of files is 0.

# %%
holdings_df = pd.read_csv("llnl_esgf_holdings.csv")
holdings_df = holdings_df.where(holdings_df.n_files > 0)
holdings_df
# Out:
#                model    scenario    variant table_id variable grid_type  \
# 0         ACCESS-CM2  historical  r10i1p1f1     Amon      tas        gn
# 1         ACCESS-CM2  historical   r1i1p1f1     Amon      tas        gn
# 2         ACCESS-CM2  historical   r2i1p1f1     Amon      tas        gn
# 3         ACCESS-CM2  historical   r3i1p1f1     Amon      tas        gn
# 4         ACCESS-CM2  historical   r4i1p1f1     Amon      tas        gn
# ...              ...         ...        ...      ...      ...       ...
# 60738  MPI-ESM1-2-LR      ssp585   r5i1p1f1     Eday     hfss        gn
# 60739  MPI-ESM1-2-LR      ssp585   r6i1p1f1     Eday     hfss        gn
# 60740  MPI-ESM1-2-LR      ssp585   r7i1p1f1     Eday     hfss        gn
# 60741  MPI-ESM1-2-LR      ssp585   r8i1p1f1     Eday     hfss        gn
# 60742  MPI-ESM1-2-LR      ssp585   r9i1p1f1     Eday     hfss        gn
#
#          version  n_files                                          filenames
# 0      v20220819      2.0  ['tas_Amon_ACCESS-CM2_historical_r10i1p1f1_gn_...
# 1      v20191108      1.0  ['tas_Amon_ACCESS-CM2_historical_r1i1p1f1_gn_1...
# 2      v20191125      1.0  ['tas_Amon_ACCESS-CM2_historical_r2i1p1f1_gn_1...
# 3      v20200306      1.0  ['tas_Amon_ACCESS-CM2_historical_r3i1p1f1_gn_1...
# 4      v20210607      1.0  ['tas_Amon_ACCESS-CM2_historical_r4i1p1f1_gn_1...
# ...          ...      ...                                                ...
# 60738  v20190710      5.0  ['hfss_Eday_MPI-ESM1-2-LR_ssp585_r5i1p1f1_gn_2...
# 60739  v20190710      5.0  ['hfss_Eday_MPI-ESM1-2-LR_ssp585_r6i1p1f1_gn_2...
# 60740  v20190710      5.0  ['hfss_Eday_MPI-ESM1-2-LR_ssp585_r7i1p1f1_gn_2...
# 60741  v20190710      5.0  ['hfss_Eday_MPI-ESM1-2-LR_ssp585_r8i1p1f1_gn_2...
# 60742  v20190710      5.0  ['hfss_Eday_MPI-ESM1-2-LR_ssp585_r9i1p1f1_gn_2...
#
# [60743 rows x 9 columns]

# %% [markdown]
# And load the specific variants for each model that were determined in `select_variants.ipynb`. (This is stored in `transfers.config.py`....)

# %%
prod_variant_lu = {
    "CNRM-CM6-1-HR": "r1i1p1f2",
    "EC-Earth3-Veg": "r1i1p1f1",
    "GFDL-ESM4": "r1i1p1f1",
    "HadGEM3-GC31-LL": "r1i1p1f3",
    "HadGEM3-GC31-MM": "r1i1p1f3",
    "KACE-1-0-G": "r1i1p1f1",
    "MIROC6": "r1i1p1f1",
    "MPI-ESM1-2-HR": "r1i1p1f1",
    "MPI-ESM1-2-LR": "r1i1p1f1",
    "MRI-ESM2-0": "r1i1p1f1",
    "NorESM2-MM": "r1i1p1f1",
    "TaiESM1": "r1i1p1f1",
    #"CESM2-WACCM": "r1i1p1f1", # compared to CESM2, this model is missing multiple variables and should be excluded (see select_variants.ipynb)
}

# %% [markdown]
# Subset the holdings using the model/variant dictionary.

# %%
results = []
for model in prod_variant_lu.keys():
    variant = prod_variant_lu[model]
    if variant is not None:
        results.append(holdings_df.query(f"model == '{model}' & variant == '{variant}'"))
    else:
        results.append(holdings_df.query(f"model == '{model}'"))
df = pd.concat(results)
df
# Out:
#                model    scenario   variant table_id variable grid_type  \
# 1514   CNRM-CM6-1-HR  historical  r1i1p1f2      day      tas        gr
# 1518   CNRM-CM6-1-HR  historical  r1i1p1f2      day   tasmax        gr
# 1520   CNRM-CM6-1-HR  historical  r1i1p1f2      day   tasmin        gr
# 1522   CNRM-CM6-1-HR  historical  r1i1p1f2      day       pr        gr
# 1524   CNRM-CM6-1-HR  historical  r1i1p1f2      day      psl        gr
# ...              ...         ...       ...      ...      ...       ...
# 47078        TaiESM1      ssp585  r1i1p1f1      day     hfls        gn
# 47079        TaiESM1      ssp585  r1i1p1f1     Eday     hfls        gn
# 47080        TaiESM1      ssp585  r1i1p1f1     Amon     hfss        gn
# 47081        TaiESM1      ssp585  r1i1p1f1      day     hfss        gn
# 47082        TaiESM1      ssp585  r1i1p1f1     Eday     hfss        gn
#
#          version  n_files                                          filenames
# 1514   v20191021      4.0  ['tas_day_CNRM-CM6-1-HR_historical_r1i1p1f2_gr...
# 1518   v20191021      4.0  ['tasmax_day_CNRM-CM6-1-HR_historical_r1i1p1f2...
# 1520   v20191021      4.0  ['tasmin_day_CNRM-CM6-1-HR_historical_r1i1p1f2...
# 1522   v20191021      7.0  ['pr_day_CNRM-CM6-1-HR_historical_r1i1p1f2_gr_...
# 1524   v20191021      4.0  ['psl_day_CNRM-CM6-1-HR_historical_r1i1p1f2_gr...
# ...          ...      ...                                                ...
# 47078  v20200902      9.0  ['hfls_day_TaiESM1_ssp585_r1i1p1f1_gn_20150101...
# 47079  v20200903      9.0  ['hfls_Eday_TaiESM1_ssp585_r1i1p1f1_gn_2015010...
# 47080  v20200901      1.0  ['hfss_Amon_TaiESM1_ssp585_r1i1p1f1_gn_201501-...
# 47081  v20200902      9.0  ['hfss_day_TaiESM1_ssp585_r1i1p1f1_gn_20150101...
# 47082  v20200903      9.0  ['hfss_Eday_TaiESM1_ssp585_r1i1p1f1_gn_2015010...
#
# [2992 rows x 9 columns]

# %% [markdown]
# ## Grids
#
# Here we will do some exploring to see what grids we will want to mirror on the ACDN. Some grids could have greater representation of variables/ frequencies etc, we want to select one that has the most. We also need to take into account the shape of the grid, as we would prefer rectangular grid shapes.
#
# So, do any grids have more data than the others for a given model and scenario?
#
# Determine the data availability for each model, scenario, and grid, in terms of number of variables x temporal frequencies. We will combine those two fields to get an idea of representation across both daily and monthly frequencies.

# %%
# create a column that is just a concatenation of temnporal frequency and variable name to simplify
df["freq_var"] = df["table_id"] + "_" + df["variable"]

# %% [markdown]
# Next, group by model, scenario, and grid type and tally the number of unique variable-table ID combinations:

# %%
rep_df = pd.DataFrame(
    df.groupby(["model", "scenario", "grid_type"])["freq_var"]
    .nunique()
)
print(rep_df)
# Out:
#                                     freq_var
# model         scenario   grid_type
# CNRM-CM6-1-HR historical gn                3
#                          gr               25
#                          gr1               1
#               ssp126     gn                5
#                          gr               44
# ...                                      ...
# TaiESM1       historical gn               45
#               ssp126     gn               48
#               ssp245     gn               48
#               ssp370     gn               45
#               ssp585     gn               48
#
# [82 rows x 1 columns]

# %% [markdown]
# Make a table for each model that shows the number of variable-table ID combinations for each grid type.

# %%
models = df.model.unique()
model_grids = {}

for model in models:
    model_df = rep_df.loc[model]
    repr_df = (
        model_df.reset_index()
        .pivot(index="grid_type", columns="scenario", values="freq_var")
    )
    print(model)
    print(repr_df, "\n")
    if len(repr_df.index)>1:
        model_grids[model] = list(repr_df.index)
# Out:
# CNRM-CM6-1-HR
# scenario   historical  ssp126  ssp245  ssp370  ssp585
# grid_type
# gn                3.0     5.0     4.0     4.0     5.0
# gr               25.0    44.0    41.0    41.0    44.0
# gr1               1.0     NaN     NaN     NaN     NaN
#
# EC-Earth3-Veg
# scenario   historical  ssp126  ssp245  ssp370  ssp585
# grid_type
# gn                  7       6       6       6       6
# gr                 50      47      47      47      47
#
# GFDL-ESM4
# scenario   historical  ssp126  ssp245  ssp370  ssp585
# grid_type
# gn                  4       5       5       5       5
# gr                  4       4       4       4       4
# gr1                45      45      42      44      42
#
# HadGEM3-GC31-LL
# scenario   historical  ssp126  ssp245  ssp585
# grid_type
# gn                 56      52      54      51
#
# HadGEM3-GC31-MM
# scenario   historical  ssp126  ssp585
# grid_type
# gn                 53      49      49
#
# KACE-1-0-G
# scenario   historical  ssp126  ssp245  ssp370  ssp585
# grid_type
# gr                 44      45      48      46      47
#
# MIROC6
# scenario   historical  ssp126  ssp245  ssp370  ssp585
# grid_type
# gn                 60      60      59      60      60
#
# MPI-ESM1-2-HR
# scenario   historical  ssp126  ssp245  ssp370  ssp585
# grid_type
# gn                 58      58      58      58      58
#
# MPI-ESM1-2-LR
# scenario   historical  ssp126  ssp245  ssp585
# grid_type
# gn                 63      63      63      63
#
# MRI-ESM2-0
# scenario   historical  ssp126  ssp245  ssp370  ssp585
# grid_type
# gn                 58      58      58      58      58
# gr                  2       2       2       2       2
#
# NorESM2-MM
# scenario   historical  ssp126  ssp245  ssp370  ssp585
# grid_type
# gn                 55      55      55      55      55
#
# TaiESM1
# scenario   historical  ssp126  ssp245  ssp370  ssp585
# grid_type
# gn                 45      48      48      45      48

# %% [markdown]
# We see there are a few models with multiple grid types. In each case it's clear to see that one grid type has the majority of the data, but we need to consider that some variables may only be available under a certain grid. Let's compare the data between grid types and see whats going on here.

# %%
model_grids
# Out:
# {'CNRM-CM6-1-HR': ['gn', 'gr', 'gr1'],
#  'EC-Earth3-Veg': ['gn', 'gr'],
#  'GFDL-ESM4': ['gn', 'gr', 'gr1'],
#  'MRI-ESM2-0': ['gn', 'gr']}

# %%
for model in model_grids.keys():
    print(f"{model}\n")
    print(f"Grids: {model_grids[model]}")
    # groupby grid type and get all freq_var combos by grid
    freq_vars = df[df['model']==model].groupby(["grid_type"])["freq_var"].apply(lambda x: list(np.unique(x)))
    # for each grid type, list the other grids and add their freq_var combos to a list of lists
    for test_grid in model_grids[model]:

        other_grid_freq_vars = []
        other_grids = model_grids[model][:]
        other_grids.remove(test_grid)

        for other_grid in other_grids:
            other_grid_freq_vars.append(freq_vars[other_grid])
        
        # then test against the other grids to find any data unique to the test grid
        unique = [t for t in freq_vars[test_grid] if t not in list(set(chain(*other_grid_freq_vars)))]    
        # and NOT unique to the test grid
        shared = [t for t in freq_vars[test_grid] if t in list(set(chain(*other_grid_freq_vars)))]
    
        print(f"Frequency/variable combos unique to grid {test_grid}:  {unique}")
        print(f"Frequency/variable combos shared with another grid besides {test_grid}: {shared}")
        print("\n")
# Out:
# CNRM-CM6-1-HR
#
# Grids: ['gn', 'gr', 'gr1']
# Frequency/variable combos unique to grid gn:  ['Omon_tos', 'SIday_siconc', 'SIday_sithick', 'SImon_siconc', 'SImon_sithick']
# Frequency/variable combos shared with another grid besides gn: ['Oday_tos']
#
#
# Frequency/variable combos unique to grid gr:  ['Amon_clt', 'Amon_evspsbl', 'Amon_hfls', 'Amon_hfss', 'Amon_hus', 'Amon_huss', 'Amon_pr', 'Amon_prsn', 'Amon_psl', 'Amon_rlds', 'Amon_rsds', 'Amon_sfcWind', 'Amon_ta', 'Amon_tas', 'Amon_tasmax', 'Amon_tasmin', 'Amon_ts', 'Amon_ua', 'Amon_uas', 'Amon_va', 'Amon_vas', 'LImon_snd', 'LImon_snw', 'Lmon_mrro', 'Lmon_mrsos', 'day_clt', 'day_hfls', 'day_hfss', 'day_hus', 'day_huss', 'day_mrro', 'day_mrsos', 'day_pr', 'day_prsn', 'day_psl', 'day_rlds', 'day_rsds', 'day_sfcWind', 'day_sfcWindmax', 'day_snw', 'day_ta', 'day_tas', 'day_tasmax', 'day_tasmin', 'day_ua', 'day_uas', 'day_va', 'day_vas', 'fx_orog', 'fx_sftlf']
# Frequency/variable combos shared with another grid besides gr: []
#
#
# Frequency/variable combos unique to grid gr1:  []
# Frequency/variable combos shared with another grid besides gr1: ['Oday_tos']
#
#
# EC-Earth3-Veg
#
# Grids: ['gn', 'gr']
# Frequency/variable combos unique to grid gn:  ['Oday_tos', 'Ofx_sftof', 'Omon_tos', 'SIday_siconc', 'SIday_sithick', 'SImon_siconc', 'SImon_sithick']
# Frequency/variable combos shared with another grid besides gn: []
#
#
# Frequency/variable combos unique to grid gr:  ['Amon_clt', 'Amon_evspsbl', 'Amon_hfls', 'Amon_hfss', 'Amon_hus', 'Amon_huss', 'Amon_pr', 'Amon_prsn', 'Amon_psl', 'Amon_rlds', 'Amon_rsds', 'Amon_sfcWind', 'Amon_ta', 'Amon_tas', 'Amon_tasmax', 'Amon_tasmin', 'Amon_ts', 'Amon_ua', 'Amon_uas', 'Amon_va', 'Amon_vas', 'Emon_mrsol', 'LImon_snd', 'LImon_snw', 'Lmon_mrro', 'Lmon_mrsos', 'Omon_prsn', 'day_clt', 'day_hfls', 'day_hfss', 'day_hus', 'day_huss', 'day_mrro', 'day_mrsos', 'day_pr', 'day_prsn', 'day_psl', 'day_rlds', 'day_rsds', 'day_sfcWind', 'day_sfcWindmax', 'day_snw', 'day_ta', 'day_tas', 'day_tasmax', 'day_tasmin', 'day_ua', 'day_uas', 'day_va', 'day_vas', 'fx_sftlf']
# Frequency/variable combos shared with another grid besides gr: []
#
#
# GFDL-ESM4
#
# Grids: ['gn', 'gr', 'gr1']
# Frequency/variable combos unique to grid gn:  []
# Frequency/variable combos shared with another grid besides gn: ['Oday_tos', 'Omon_tos', 'SImon_siconc', 'SImon_sithick', 'fx_orog']
#
#
# Frequency/variable combos unique to grid gr:  []
# Frequency/variable combos shared with another grid besides gr: ['Oday_tos', 'Omon_tos', 'SImon_siconc', 'SImon_sithick']
#
#
# Frequency/variable combos unique to grid gr1:  ['Amon_clt', 'Amon_evspsbl', 'Amon_hfls', 'Amon_hfss', 'Amon_hus', 'Amon_huss', 'Amon_pr', 'Amon_prsn', 'Amon_psl', 'Amon_rlds', 'Amon_rsds', 'Amon_sfcWind', 'Amon_ta', 'Amon_tas', 'Amon_tasmax', 'Amon_tasmin', 'Amon_ts', 'Amon_ua', 'Amon_uas', 'Amon_va', 'Amon_vas', 'Emon_mrsol', 'Emon_rls', 'Emon_rss', 'LImon_snd', 'LImon_snw', 'Lmon_mrro', 'Lmon_mrsos', 'day_huss', 'day_mrro', 'day_mrsos', 'day_pr', 'day_prsn', 'day_psl', 'day_rlds', 'day_rsds', 'day_sfcWind', 'day_sfcWindmax', 'day_snw', 'day_tas', 'day_tasmax', 'day_tasmin', 'day_uas', 'day_vas', 'fx_sftlf']
# Frequency/variable combos shared with another grid besides gr1: ['fx_orog']
#
#
# MRI-ESM2-0
#
# Grids: ['gn', 'gr']
# Frequency/variable combos unique to grid gn:  ['Amon_clt', 'Amon_evspsbl', 'Amon_hfls', 'Amon_hfss', 'Amon_hus', 'Amon_huss', 'Amon_pr', 'Amon_prsn', 'Amon_psl', 'Amon_rlds', 'Amon_rsds', 'Amon_sfcWind', 'Amon_ta', 'Amon_tas', 'Amon_tasmax', 'Amon_tasmin', 'Amon_ts', 'Amon_ua', 'Amon_uas', 'Amon_va', 'Amon_vas', 'Emon_mrsol', 'LImon_snd', 'LImon_snw', 'Lmon_mrro', 'Lmon_mrsos', 'Ofx_sftof', 'SIday_siconc', 'SIday_sithick', 'SImon_siconc', 'SImon_sithick', 'day_clt', 'day_hfls', 'day_hfss', 'day_hus', 'day_huss', 'day_mrro', 'day_mrsos', 'day_pr', 'day_prsn', 'day_psl', 'day_rlds', 'day_rsds', 'day_sfcWind', 'day_sfcWindmax', 'day_snw', 'day_ta', 'day_tas', 'day_tasmax', 'day_tasmin', 'day_ua', 'day_uas', 'day_va', 'day_vas', 'fx_orog', 'fx_sftlf']
# Frequency/variable combos shared with another grid besides gn: ['Oday_tos', 'Omon_tos']
#
#
# Frequency/variable combos unique to grid gr:  []
# Frequency/variable combos shared with another grid besides gr: ['Oday_tos', 'Omon_tos']

# %% [markdown]
# It looks like we can choose a single grid to capture all freq/var combos for two of these models (GFDL-ESM4 and MRI-ESM2-0), but will need multiple grids to capture all freq/var combos for the other two (CNRM-CM6-1-HR and EC-Earth3-Veg).  Here are the results of the grid selection:

# %%
prod_grid_lu = {
    "CNRM-CM6-1-HR": ["gn", "gr"],
    "EC-Earth3-Veg": ["gn", "gr"],
    "GFDL-ESM4": "gr1",
    "HadGEM3-GC31-LL": "gn",
    "HadGEM3-GC31-MM": "gn",
    "KACE-1-0-G": "gr",
    "MIROC6": "gn",
    "MPI-ESM1-2-HR": "gn",
    "MPI-ESM1-2-LR": "gn",
    "MRI-ESM2-0": "gn",
    "NorESM2-MM": "gn",
    "TaiESM1": "gn",
}
