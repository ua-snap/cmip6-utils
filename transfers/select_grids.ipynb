# %% [markdown]
# # Explore LLNL ESGF holdings
#
# Use this notebook to explore the LLNL ESGF holdings and determine which grid we should use for each of the models. Most models only have one grid, but some have more and we need to explicitly define the best choice. The bottom of the notebook includes the justification for each model.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Read a CSV containing info on holdings. Since empty directories are listed here, remove any rows where number of files is 0.

# %%
holdings_df = pd.read_csv("llnl_esgf_holdings.csv")
holdings_df = holdings_df.where(holdings_df.n_files > 0)
holdings_df
# Out:
#                model    scenario    variant table_id variable grid_type  \
# 0         ACCESS-CM2  historical  r10i1p1f1     Amon      tas        gn
# 1         ACCESS-CM2  historical   r1i1p1f1     Amon      tas        gn
# 2         ACCESS-CM2  historical   r2i1p1f1     Amon      tas        gn
# 3         ACCESS-CM2  historical   r3i1p1f1     Amon      tas        gn
# 4         ACCESS-CM2  historical   r4i1p1f1     Amon      tas        gn
# ...              ...         ...        ...      ...      ...       ...
# 57150  MPI-ESM1-2-LR      ssp585   r5i1p1f1     Eday     hfss        gn
# 57151  MPI-ESM1-2-LR      ssp585   r6i1p1f1     Eday     hfss        gn
# 57152  MPI-ESM1-2-LR      ssp585   r7i1p1f1     Eday     hfss        gn
# 57153  MPI-ESM1-2-LR      ssp585   r8i1p1f1     Eday     hfss        gn
# 57154  MPI-ESM1-2-LR      ssp585   r9i1p1f1     Eday     hfss        gn
#
#          version  n_files                                          filenames
# 0      v20220819      2.0  ['tas_Amon_ACCESS-CM2_historical_r10i1p1f1_gn_...
# 1      v20191108      1.0  ['tas_Amon_ACCESS-CM2_historical_r1i1p1f1_gn_1...
# 2      v20191125      1.0  ['tas_Amon_ACCESS-CM2_historical_r2i1p1f1_gn_1...
# 3      v20200306      1.0  ['tas_Amon_ACCESS-CM2_historical_r3i1p1f1_gn_1...
# 4      v20210607      1.0  ['tas_Amon_ACCESS-CM2_historical_r4i1p1f1_gn_1...
# ...          ...      ...                                                ...
# 57150  v20190710      5.0  ['hfss_Eday_MPI-ESM1-2-LR_ssp585_r5i1p1f1_gn_2...
# 57151  v20190710      5.0  ['hfss_Eday_MPI-ESM1-2-LR_ssp585_r6i1p1f1_gn_2...
# 57152  v20190710      5.0  ['hfss_Eday_MPI-ESM1-2-LR_ssp585_r7i1p1f1_gn_2...
# 57153  v20190710      5.0  ['hfss_Eday_MPI-ESM1-2-LR_ssp585_r8i1p1f1_gn_2...
# 57154  v20190710      5.0  ['hfss_Eday_MPI-ESM1-2-LR_ssp585_r9i1p1f1_gn_2...
#
# [57155 rows x 9 columns]

# %% [markdown]
# And load the specific variants for each model that were determined in `select_variants.ipynb`. (This is stored in `transfers.config.py`.... right now I have included empty values for models that still need to be assessed.)

# %%
prod_variant_lu = {
    "CNRM-CM6-1-HR": "r1i1p1f2",
    "EC-Earth3-Veg": "r1i1p1f1",
    "GFDL-ESM4": "r1i1p1f1",
    "HadGEM3-GC31-LL": "r1i1p1f3",
    "HadGEM3-GC31-MM": "r1i1p1f3",
    "KACE-1-0-G": "r1i1p1f1",
    "MIROC6": "r1i1p1f1",
    "MPI-ESM1-2-HR": "r1i1p1f1",
    "MPI-ESM1-2-LR": None,
    "MRI-ESM2-0": "r1i1p1f1",
    "NorESM2-MM": "r1i1p1f1",
    "TaiESM1": "r1i1p1f1",
    "CESM2-WACCM": "r1i1p1f1",
    "E3SM-1-0": None,
    "E3SM-1-1-ECA": None,
    "E3SM-2-0": None,
    "E3SM-2-0-NARRM": None,
}

# %% [markdown]
# Subset the holdings using the model/variant dictionary.

# %%
results = []
for model in prod_variant_lu.keys():
    variant = prod_variant_lu[model]
    if variant is not None:
        results.append(holdings_df.query(f"model == '{model}' & variant == '{variant}'"))
    else:
        results.append(holdings_df.query(f"model == '{model}'"))
df = pd.concat(results)
df
# Out:
#                model    scenario   variant table_id variable grid_type  \
# 1492   CNRM-CM6-1-HR  historical  r1i1p1f2      day      tas        gr
# 1496   CNRM-CM6-1-HR  historical  r1i1p1f2      day   tasmax        gr
# 1498   CNRM-CM6-1-HR  historical  r1i1p1f2      day   tasmin        gr
# 1500   CNRM-CM6-1-HR  historical  r1i1p1f2      day       pr        gr
# 1502   CNRM-CM6-1-HR  historical  r1i1p1f2      day      psl        gr
# ...              ...         ...       ...      ...      ...       ...
# 43346    CESM2-WACCM      ssp585  r1i1p1f1    SIday  sithick        gn
# 43351    CESM2-WACCM      ssp585  r1i1p1f1     Amon     hfls        gn
# 43356    CESM2-WACCM      ssp585  r1i1p1f1      day     hfls        gn
# 43366    CESM2-WACCM      ssp585  r1i1p1f1     Amon     hfss        gn
# 43371    CESM2-WACCM      ssp585  r1i1p1f1      day     hfss        gn
#
#          version  n_files                                          filenames
# 1492   v20191021      4.0  ['tas_day_CNRM-CM6-1-HR_historical_r1i1p1f2_gr...
# 1496   v20191021      4.0  ['tasmax_day_CNRM-CM6-1-HR_historical_r1i1p1f2...
# 1498   v20191021      4.0  ['tasmin_day_CNRM-CM6-1-HR_historical_r1i1p1f2...
# 1500   v20191021      7.0  ['pr_day_CNRM-CM6-1-HR_historical_r1i1p1f2_gr_...
# 1502   v20191021      4.0  ['psl_day_CNRM-CM6-1-HR_historical_r1i1p1f2_gr...
# ...          ...      ...                                                ...
# 43346  v20200702      5.0  ['sithick_SIday_CESM2-WACCM_ssp585_r1i1p1f1_gn...
# 43351  v20200702      5.0  ['hfls_Amon_CESM2-WACCM_ssp585_r1i1p1f1_gn_201...
# 43356  v20200702     29.0  ['hfls_day_CESM2-WACCM_ssp585_r1i1p1f1_gn_2015...
# 43366  v20200702      5.0  ['hfss_Amon_CESM2-WACCM_ssp585_r1i1p1f1_gn_201...
# 43371  v20200702     29.0  ['hfss_day_CESM2-WACCM_ssp585_r1i1p1f1_gn_2015...
#
# [13537 rows x 9 columns]

# %% [markdown]
# ## Grids
#
# Here we will do some exploring to see what grids we will want to mirror on the ACDN. Some grids could have greater representation of variables/ frequencies etc, we want to select one that has the most. We also need to take into account the shape of the grid, as we would prefer rectangular grid shapes.
#
# So, do any grids have more data than the others for a given model and scenario?
#
# Determine the data availability for each model, scenario, and grid, in terms of number of variables x temporal frequencies. We will combine those two fields to get an idea of representation across both daily and monthly frequencies.

# %%
# create a column that is just a concatenation of temnporal frequency and variable name to simplify
df["freq_var"] = df["table_id"] + "_" + df["variable"]

# %% [markdown]
# Next, group by model, scenario, and grid type and tally the number of unique variable-table ID combinations:

# %%
rep_df = pd.DataFrame(
    df.groupby(["model", "scenario", "grid_type"])["freq_var"]
    .nunique()
)
rep_df
# Out:
#                                   freq_var
# model       scenario   grid_type
# CESM2-WACCM historical gn               46
#             ssp126     gn               51
#             ssp245     gn               44
#             ssp370     gn               44
#             ssp585     gn               52
# ...                                    ...
# TaiESM1     historical gn               45
#             ssp126     gn               48
#             ssp245     gn               48
#             ssp370     gn               45
#             ssp585     gn               48
#
# [71 rows x 1 columns]

# %% [markdown]
# Make a table for each model that shows the number of variable-table ID combinations for each grid type.

# %%
models = df.model.unique()
model_grids = {}

for model in models:
    model_df = rep_df.loc[model]
    repr_df = (
        model_df.reset_index()
        .pivot(index="grid_type", columns="scenario", values="freq_var")
    )
    print(model)
    print(repr_df, "\n")
    if len(repr_df.index)>1:
        model_grids[model] = list(repr_df.index)
# Out:
# CNRM-CM6-1-HR
# scenario   historical  ssp126  ssp245  ssp370  ssp585
# grid_type
# gn                  3       5       4       4       5
# gr                 25      44      41      41      44
#
# EC-Earth3-Veg
# scenario   historical  ssp126  ssp245  ssp370  ssp585
# grid_type
# gn                  7       6       6       6       6
# gr                 50      47      47      47      47
#
# GFDL-ESM4
# scenario   historical  ssp126  ssp245  ssp370  ssp585
# grid_type
# gn                  4       5       5       5       5
# gr1                45      44      41      43      41
#
# HadGEM3-GC31-LL
# scenario   historical  ssp126  ssp245  ssp585
# grid_type
# gn                 56      52      54      52
#
# HadGEM3-GC31-MM
# scenario   historical  ssp126  ssp585
# grid_type
# gn                 53      48      48
#
# KACE-1-0-G
# scenario   historical  ssp126  ssp245  ssp370  ssp585
# grid_type
# gr                 44      45      48      46      47
#
# MIROC6
# scenario   historical  ssp126  ssp245  ssp370  ssp585
# grid_type
# gn                 60      60      59      60      60
#
# MPI-ESM1-2-HR
# scenario   ssp126  ssp245  ssp370  ssp585
# grid_type
# gn             58      58      58      58
#
# MPI-ESM1-2-LR
# scenario   historical  ssp126  ssp245  ssp370  ssp585
# grid_type
# gn                 63      63      63      63      63
#
# NorESM2-MM
# scenario   historical  ssp126  ssp245  ssp370  ssp585
# grid_type
# gn                 55      55      55      55      55
#
# TaiESM1
# scenario   historical  ssp126  ssp245  ssp370  ssp585
# grid_type
# gn                 45      48      48      45      48
#
# CESM2-WACCM
# scenario   historical  ssp126  ssp245  ssp370  ssp585
# grid_type
# gn                 46      51      44      44      52

# %% [markdown]
# We see there are a few models with multiple grid types. In each case it's clear to see that one grid type has the majority of the data, but we need to consider that some variables may only be available under a certain grid. Let's compare the data between grid types and see whats going on here.

# %%
model_grids
# Out:
# {'CNRM-CM6-1-HR': ['gn', 'gr'],
#  'EC-Earth3-Veg': ['gn', 'gr'],
#  'GFDL-ESM4': ['gn', 'gr1']}

# %%
for model in model_grids.keys():
    freq_vars = df[df['model']==model].groupby(["grid_type"])["freq_var"].apply(lambda x: list(np.unique(x)))
    #assumes only 2 grids to compare, and that the second grid will has more data than the first
    print(model, ": ")
    print(f"Freq/vars common to both grids {model_grids[model]} : ", list(set(freq_vars[model_grids[model][0]]).intersection(set(freq_vars[model_grids[model][1]]))))
    print(f"Freq/vars unique to minority grid {model_grids[model][0]} : ", list(set(freq_vars[model_grids[model][0]]).difference(set(freq_vars[model_grids[model][1]]))))
    print(f"Freq/vars unique to majority grid {model_grids[model][1]} : ", list(set(freq_vars[model_grids[model][1]]).difference(set(freq_vars[model_grids[model][0]]))))
    print("\n")
# Out:
# CNRM-CM6-1-HR :
# Freq/vars common to both grids ['gn', 'gr'] :  []
# Freq/vars unique to minority grid gn :  ['SIday_siconc', 'SIday_sithick', 'Oday_tos', 'Omon_tos', 'SImon_siconc', 'SImon_sithick']
# Freq/vars unique to majority grid gr :  ['day_va', 'day_ua', 'Amon_rsds', 'day_psl', 'Amon_tasmax', 'Amon_hfss', 'day_hfls', 'Amon_vas', 'Amon_psl', 'day_vas', 'Amon_ua', 'Amon_va', 'day_mrsos', 'day_sfcWind', 'Amon_ta', 'Amon_tasmin', 'LImon_snd', 'Amon_ts', 'Amon_huss', 'Amon_hfls', 'day_uas', 'day_tasmax', 'fx_orog', 'Amon_clt', 'day_mrro', 'fx_sftlf', 'Amon_evspsbl', 'day_pr', 'LImon_snw', 'Amon_sfcWind', 'Amon_rlds', 'Amon_uas', 'Lmon_mrsos', 'day_huss', 'Amon_tas', 'day_rlds', 'day_hfss', 'day_ta', 'Amon_prsn', 'day_snw', 'Lmon_mrro', 'day_tasmin', 'day_hus', 'day_sfcWindmax', 'day_tas', 'Amon_pr', 'Amon_hus', 'day_prsn', 'day_rsds', 'day_clt']
#
#
# EC-Earth3-Veg :
# Freq/vars common to both grids ['gn', 'gr'] :  []
# Freq/vars unique to minority grid gn :  ['SIday_siconc', 'SIday_sithick', 'Oday_tos', 'Omon_tos', 'Ofx_sftof', 'SImon_siconc', 'SImon_sithick']
# Freq/vars unique to majority grid gr :  ['day_va', 'day_ua', 'Amon_rsds', 'day_psl', 'Amon_tasmax', 'Amon_hfss', 'day_hfls', 'Amon_vas', 'Amon_psl', 'day_vas', 'Amon_ua', 'Amon_va', 'day_mrsos', 'day_sfcWind', 'Amon_ta', 'Amon_tasmin', 'LImon_snd', 'Amon_ts', 'Amon_huss', 'Amon_hfls', 'day_uas', 'day_tasmax', 'Amon_clt', 'day_mrro', 'fx_sftlf', 'Amon_evspsbl', 'Emon_mrsol', 'Omon_prsn', 'LImon_snw', 'day_pr', 'Amon_sfcWind', 'Amon_rlds', 'Amon_uas', 'Lmon_mrsos', 'day_huss', 'Amon_tas', 'day_rlds', 'day_hfss', 'day_ta', 'Amon_prsn', 'day_snw', 'Lmon_mrro', 'day_tasmin', 'day_hus', 'day_sfcWindmax', 'day_tas', 'Amon_pr', 'Amon_hus', 'day_prsn', 'day_rsds', 'day_clt']
#
#
# GFDL-ESM4 :
# Freq/vars common to both grids ['gn', 'gr1'] :  ['fx_orog']
# Freq/vars unique to minority grid gn :  ['SImon_siconc', 'Omon_tos', 'SImon_sithick', 'Oday_tos']
# Freq/vars unique to majority grid gr1 :  ['Amon_rsds', 'day_psl', 'Amon_tasmax', 'Amon_hfss', 'day_vas', 'Amon_vas', 'Amon_psl', 'Amon_ua', 'Amon_va', 'Emon_rss', 'day_mrsos', 'Amon_ta', 'Amon_tasmin', 'day_sfcWind', 'LImon_snd', 'Amon_ts', 'Amon_huss', 'Amon_hfls', 'day_uas', 'day_tasmax', 'Amon_clt', 'day_mrro', 'fx_sftlf', 'Amon_evspsbl', 'Emon_mrsol', 'day_pr', 'LImon_snw', 'Amon_sfcWind', 'Amon_rlds', 'Amon_uas', 'Lmon_mrsos', 'Emon_rls', 'day_huss', 'Amon_tas', 'day_rlds', 'Amon_prsn', 'day_snw', 'Lmon_mrro', 'day_tasmin', 'day_sfcWindmax', 'day_tas', 'Amon_pr', 'Amon_hus', 'day_prsn', 'day_rsds']

# %% [markdown]
# Here are the results of the grid selection:

# %%
#TBD!

prod_grid_lu = {
    "CNRM-CM6-1-HR": ,
    "EC-Earth3-Veg": ,
    "GFDL-ESM4": ,
    "HadGEM3-GC31-LL": ,
    "HadGEM3-GC31-MM": ,
    "KACE-1-0-G": ,
    "MIROC6": ,
    "MPI-ESM1-2-HR": ,
    "MPI-ESM1-2-LR": ,
    "MRI-ESM2-0": ,
    "NorESM2-MM": ,
    "TaiESM1": ,
    "CESM2-WACCM": ,
    "E3SM-1-0": ,
    "E3SM-1-1-ECA": ,
    "E3SM-2-0": ,
    "E3SM-2-0-NARRM": ,
}
